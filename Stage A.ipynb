# %%
import numpy as np # linear algebra
import pandas as pd # data processing

# %%
df=pd.read_csv(r'C:\Users\EliteBook\Desktop\downloaded.csv')

# %%
df.describe(include='all')
# Out:
#                     record_id  utility_id_ferc1   report_year  \
# count                   29523      29523.000000  29523.000000
# unique                  29523               NaN           NaN
# top     f1_fuel_2009_12_2_0_4               NaN           NaN
# freq                        1               NaN           NaN
# mean                      NaN        118.601836   2005.806050
# std                       NaN         74.178353      7.025483
# min                       NaN          1.000000   1994.000000
# 25%                       NaN         55.000000   2000.000000
# 50%                       NaN        122.000000   2006.000000
# 75%                       NaN        176.000000   2012.000000
# max                       NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# unique             2315                   6         9              NaN
# ...

# %% [markdown]
# QUESTION 4: the values for the standard deviation under the 75 percentile can be found on the describe table function

# %%
df.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %% [markdown]
# QUESTION ONE

# %%
a=[1,2,3,4,5,6]
b=[13,21,34]

# %%
A_B=a+b

# %%
A_B
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34]

# %% [markdown]
# QUESTION 2:

# %%
np.identity(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# testing for skewness and kurtosis

# %%
df['fuel_qty_burned'].skew()
# Out:
# 15.851495469109503

# %%
df['fuel_qty_burned'].kurt()
# Out:
# 651.3694501337732

# %%
df['fuel_cost_per_unit_burned'].mean()
# Out:
# 208.64903102665716

# %%
df['report_year']==.max()
# Out:
# 7964521.0

# %% [markdown]
# question 6

# %%
df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %% [markdown]
# the fuel unit has a total number of 180 missing values

# %% [markdown]
# QUESTION 9

# %%
year_94=df[(df['fuel_type_code_pudl']=='coal') & (df['report_year']==1994)]
year_98=df[(df['fuel_type_code_pudl']=='coal') & (df['report_year']==1998)]
year_94.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 5  f1_fuel_1994_12_2_0_13                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 5   e. c. gaston-unit 5                coal       ton        2124933.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
year94_sum = year_94['fuel_cost_per_unit_burned'].sum()
year98_sum = year_98['fuel_cost_per_unit_burned'].sum()

# %%
percent_change = ((year98_sum-year94_sum)/year94_sum)*100

# %%
print(percent_change)
# Out:
# -20.56765451826053

# %%
#the year with the highest fuel cost per unit

# %% [markdown]
# QUESTION 10

# %%
years = list(range(1994,2019))

# %%
d= []
e= {}
for i in years:
    e[i] = []
    v = df[(df['report_year']==i)]
    w = v['fuel_cost_per_unit_delivered'].mean()
    d.append(w)
    for j in d:
        if i in e:
            e[i]. append(j)

# %%
e
# Out:
# {1994: [63.636059919028284],
#  1995: [63.636059919028284, 32.73526894254789],
#  1996: [63.636059919028284, 32.73526894254789, 9196.7059476103],
#  1997: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813],
#  1998: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813,
#   287.15442005420147],
#  1999: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813,
#   287.15442005420147,
#   25.551626666666632],
#  2000: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813,
#   287.15442005420147,
#   25.551626666666632,
#   985.3628769118723],
#  2001: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813,
#   287.15442005420147,
#   25.551626666666632,
#   985.3628769118723,
#   60.050396017699086],
#  2002: [63.636059919028284,
#   32.73526894254789,
#   9196.7059476103,
#   11140.19723948813,
#   287.15442005420147,
# ...

# %% [markdown]
# # thank you hamoye for this opportunity
